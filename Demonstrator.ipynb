# %%
import csv
import json
import pandas as pd
import numpy as np
import argparse

from IPython.display import display, HTML
from utils.data_utils import get_data
from utils.constants import *
from utils.prompt_utils import * 
from utils.result_utils import *
from utils.run_utils import *

from main import *

display(HTML(f"<style>table td, table th {{ font-size: 14px; }}</style>"))
# Out:
# <style>table td, table th { font-size: 14px; }</style>

# %% [markdown]
# # Load the data

# %% [markdown]
# ### Loading the Magellan datasets

# %% [markdown]
# Assuming the datsets have been downloaded (```python utils/download_datasets.py```), we can find the datasets in the ```Input``` folder. For a full list of available datasets, see the README.

# %%
dataset = "dblp_acm"
candidate_pairs = get_data(dataset)
candidate_pairs = candidate_pairs[["title_x","year_x", "title_y", "year_y", "label_str"]][:10]

# %% [markdown]
# # Running Experiments

# %% [markdown]
# ### Small Example

# %%
# Choose model (gpt-3, gpt-4, gpt-4o) and prompt method (natural, json, yaml etc.)
model = MODEL_NAMES["gpt-3"]
prompt_method = PROMPT_METHODS["natural"]

dataset_type = DATASET_TYPE[dataset]
title_col = DATASET_TITLES[dataset]
total_pairs = len(candidate_pairs)

trial_metrics = {
    "prec": [],
    "rec": [],
    "f1": [],
    "acc": [],
    "time": [],
    "details": [],
}

# List for predictions
preds = []
# Go through each pair of candidates and prompt the model for a prediction
for i in range(total_pairs):
    print(f"Run {i+1}/{total_pairs}")

    # Get the prompt in the desired format
    prompt_data = prompt_method(candidate_pairs.iloc[i], COLUMNS[dataset], dataset_type)
    # Pass the prompt as a list of messages
    messages = prompt(data = prompt_data, category = dataset_type, title_col = title_col)
    
    prompt_str = messages[0]["content"]
    print(f"{prompt_str}\n")
    
    try:
        # Get the completion from the Model
        response_raw, logprob = get_completion_from_messages(messages, model)
        # Make sure the answer is Yes or No
        pred = extract_answer(response_raw.lower())
        preds.append(extract_answer(response_raw.lower()))

        # Set the predicted label in the candidate_pairs DataFrame
        candidate_pairs.at[i, "predicted_label"] = pred
        candidate_pairs.iloc[i, candidate_pairs.columns.get_loc("predicted_label")] = pred

        # The ground truth label in string format
        actual_label = candidate_pairs.iloc[i]["label_str"].lower()

        # Log the prediction vs. actual
        print(f"Prediction: {pred} | Actual: {actual_label}\n\n")

    except openai.OpenAIError as e:
        print(f"Service Unavailable Error: {e}")
        continue
        
# Extract Ground Truth Labels
gt = candidate_pairs["label_str"][:total_pairs]

# Compute Metrics
prec, rec, acc, f1 = compute_metrics(preds, gt, candidate_pairs)

print(f"F1-Score: {f1}")
print(f"Precision: {prec}")
print(f"Recall: {rec}")
print(f"Accuracy: {acc}")
# Out:
# Run 1/10
# Are Publication A and Publication B the same? Yes or No? Publication A is titled 'a query language and optimization techniques for unstructured data', 1996. Publication B is titled 'fundamental techniques for order optimization', 1996. Are Publication A and Publication B the same?
#
# Prediction: no | Actual: no
#
#
# Run 2/10
# Are Publication A and Publication B the same? Yes or No? Publication A is titled 'secure transaction processing in firm real-time database systems', 1997. Publication B is titled 'a database system for real-time event aggregation in telecommunication', 1998. Are Publication A and Publication B the same?
#
# Prediction: no | Actual: no
#
#
# Run 3/10
# Are Publication A and Publication B the same? Yes or No? Publication A is titled 'navigating large-scale semi-structured data in business portals', 2001. Publication B is titled 'navigating large-scale semi-structured data in business portals', 2001. Are Publication A and Publication B the same?
#
# Prediction: yes | Actual: yes
#
#
# Run 4/10
# Are Publication A and Publication B the same? Yes or No? Publication A is titled 'view management in multimedia databases', 2000. Publication B is titled 'efficient user-adaptable similarity search in large multimedia databases', 1997. Are Publication A and Publication B the same?
#
# Prediction: no | Actual: no
#
#
# Run 5/10
# Are Publication A and Publication B the same? Yes or No? Publication A is titled 'automated selection of materialized views and indexes in sql databases', 2000. Publication B is titled 'automated selection of materialized views and indexes in sql databases', 2000. Are Publication A and Publication B the same?
#
# Prediction: yes | Actual: yes
#
#
# Run 6/10
# Are Publication A and Publication B the same? Yes or No? Publication A is titled 'secure and portable database extensibility', 1998. Publication B is titled 'the montage extensible datablade architecture', 1994. Are Publication A and Publication B the same?
#
# Prediction: no | Actual: no
#
#
# Run 7/10
# Are Publication A and Publication B the same? Yes or No? Publication A is titled 'partitioned garbage collection of large object store', 1997. Publication B is titled 'partition selection policies in object database garbage collection', 1994. Are Publication A and Publication B the same?
#
# Prediction: no | Actual: no
#
#
# Run 8/10
# Are Publication A and Publication B the same? Yes or No? Publication A is titled 'lh * - a scalable , distributed data structure', 1996. Publication B is titled 'lh * - a scalable , distributed data structure', 1996. Are Publication A and Publication B the same?
#
# Prediction: yes | Actual: yes
#
#
# Run 9/10
# Are Publication A and Publication B the same? Yes or No? Publication A is titled 'the wasa2 object-oriented workflow management system', 1999. Publication B is titled 'the ores temporal database management system', 1994. Are Publication A and Publication B the same?
#
# Prediction: no | Actual: no
#
#
# Run 10/10
# Are Publication A and Publication B the same? Yes or No? Publication A is titled 'binding propagation in disjunctive databases', 1998. Publication B is titled 'binding propagation in disjunctive databases', 1998. Are Publication A and Publication B the same?
#
# Prediction: yes | Actual: yes
#
#
# F1-Score: 1.0
# Precision: 1.0
# Recall: 1.0
# Accuracy: 1.0

# %% [markdown]
# ### Larger example

# %% [markdown]
# ##### Define the arguments

# %%
args = argparse.Namespace(
    output_folder='output', # Folder to store results
    dataset='dblp_gs',      # Dataset to use
    prompt_format='natural',# Format to use (json, tabular, yaml, natural)
    improvement='basic',    # Improvements (short additional message to guide the model, basic = no message)
    k=0,                    # Number of examples to use in prompt
    num_pairs=50,           # Number of pairs to compare (Dataset size is default)
    llm='gpt-3',            # The model to use
    context=True,           # Changes 'Entity' to suitable description ('Publication', 'Product', 'Song' etc.)
    chain_of_thought=False, # Chaing of thought Ask the model to extract 'yes' or 'no' from the answer
    do_train=False,         # Use the training data instead for prompting
    category_pair = None,
    category_distribution = None,
)

# %% [markdown]
# ##### Run the matching

# %%
run_entity_matching(args)
# Out:
#        INFO     2024-12-20 17:58:01,835 [utils.data_utils]  	[INFO] - Loading data from input/Structured/DBLP-GoogleScholar
#        INFO     2024-12-20 17:58:01,992 [root]  	[INFO] - Running the matching on 50 examples
#        INFO     2024-12-20 17:58:01,992 [root]  	[INFO] - Run 1/50
#        INFO     2024-12-20 17:58:01,993 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'interview with jim gray', 2003. Publication B is titled 'interview with authors', e larson, san diego . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:02,522 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:02,525 [root]  	[INFO] - Run 2/50
#        INFO     2024-12-20 17:58:02,527 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'schemasql - a language for interoperability in relational multi-database systems', l lakshmanan , f sadri , i subramanian, vldb, 1996. Publication B is titled 'panel : interoperability in multidatabases : semantic and systems issues', y breitbartâ ? ¦, proc of vldb . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:02,928 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:02,934 [root]  	[INFO] - Run 3/50
#        INFO     2024-12-20 17:58:02,937 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'olap , relational , and multidimensional database systems', g colliat, sigmod record, 1996. Publication B is titled 'cmd : a multidimensional declustering method for parallel database systems', l jianzhong , j srivastava , d rotem, proceedings of international conference on vldb , august . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:03,646 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:03,648 [root]  	[INFO] - Run 4/50
#        INFO     2024-12-20 17:58:03,656 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'data integration and warehousing in telecom italia', s trisolini , m lenzerini , d nardi, sigmod conference, 1999. Publication B is titled 'enterprise modeling and data warehousing in telecom italia', d calvanese , l dragone , d nardi , r rosati , sm. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:04,055 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:04,058 [root]  	[INFO] - Run 5/50
#        INFO     2024-12-20 17:58:04,063 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'formal query languages for secure relational databases', m winslett , k smith , x qian, acm trans . database syst ., 1994. Publication B is titled 'on completeness of historical relational query languages', j clifford , a croker , a tuzhilin, acm transactions on database systems ( tods ) ,, 1994.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:06,860 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:06,862 [root]  	[INFO] - Run 6/50
#        INFO     2024-12-20 17:58:06,867 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'guest editor s introduction', 2002. Publication B is titled 'guest editorial', c allocchio, computer networks ,, 2000.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:07,227 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:07,228 [root]  	[INFO] - Run 7/50
#        INFO     2024-12-20 17:58:07,231 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'metadata for multimedia documents', k bіhm , t rakow, sigmod record, 1994. Publication B is titled 'multimedia documents with elastic time', my kim , j song, & hellip ; of the third acm international conference on multimedia ,, 1995.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:07,737 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:07,739 [root]  	[INFO] - Run 8/50
#        INFO     2024-12-20 17:58:07,741 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'database research at the university of illinois at urbana-champaign', m winslett , k chang , a doan , j han , c zhai , y zhou, sigmod record, 2002. Publication B is titled 'university of illinois , urbana', ms bsee, ph. d. , university of california , santa. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:08,155 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:08,157 [root]  	[INFO] - Run 9/50
#        INFO     2024-12-20 17:58:08,160 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'processing sliding window multi-joins in continuous queries over data streams', l golab , m жzsu, vldb, 2003. Publication B is titled 'continuous queries over data streams', s balu , j widom. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:08,665 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:08,668 [root]  	[INFO] - Run 10/50
#        INFO     2024-12-20 17:58:08,672 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'indexing the positions of continuously moving objects', s saltenis , c jensen , s leutenegger , m lopez, sigmod conference, 2000. Publication B is titled 'lopez. , m. : indexing the position of continuously moving objects', s saltenis , c jensen , s leutenegger, proceedings of acm sigmod conference. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#        INFO     2024-12-20 17:58:08,968 [utils.run_utils]  	[INFO] - Prediction: yes | Actual: yes
#        INFO     2024-12-20 17:58:08,972 [root]  	[INFO] - Run 11/50
#        INFO     2024-12-20 17:58:08,974 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'opt + + : an object-oriented implementation for extensible database query optimization', n kabra , d dewitt, vldb j., 1999. Publication B is titled 'description logics for semantic query optimization in object-oriented database systems', d beneventano , s bergamaschi , c sartori, acm transactions on database systems ,, 2003.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:09,281 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:09,283 [root]  	[INFO] - Run 12/50
#        INFO     2024-12-20 17:58:09,291 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'reminiscences on influential papers', 1999. Publication B is titled 'reminiscences on influential papers', e bertino, acm transactions on database systems ,, 1976.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:09,611 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:09,614 [root]  	[INFO] - Run 13/50
#        INFO     2024-12-20 17:58:09,616 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'deeds towards a distributed and active real-time database system', s andler , j hansson , j eriksson , j mellin , m berndtsson , b eftring, sigmod record, 1996. Publication B is titled 'andb . eftring , deeds : towards a distributed and active real-time database systems', sf andler , j hansson , j eriksson , j mellin , m, acm sigmod record . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:09,999 [utils.run_utils]  	[INFO] - Prediction: no | Actual: yes
#        INFO     2024-12-20 17:58:10,000 [root]  	[INFO] - Run 14/50
#        INFO     2024-12-20 17:58:10,001 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'a language based multidatabase system', e kќhn , t tschernko , k schwarz, sigmod conference, 1994. Publication B is titled 'interbase : a multidatabase prototype system', oa bukhres , j chen , ak elmagarmid , x liu , jg. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:10,328 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:10,330 [root]  	[INFO] - Run 15/50
#        INFO     2024-12-20 17:58:10,332 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'dynamic itemset counting and implication rules for market basket data', s brin , r motwani , j ullman , s tsur, sigmod conference, 1997. Publication B is titled 'dynamic iternset counting and impficalion rules for market basket data', s brin , r motwani , jd ullman , s tsur, acm sigmod international conference on the management of & hellip ; . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:10,637 [utils.run_utils]  	[INFO] - Prediction: no | Actual: yes
#        INFO     2024-12-20 17:58:10,640 [root]  	[INFO] - Run 16/50
#        INFO     2024-12-20 17:58:10,643 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'efficiently instantiating view-objects from remote relational databases', b lee , g wiederhold, vldb j., 1994. Publication B is titled 'simple random sampling from relational databases', fo or861 , d rotem, proc . of vldb , kyoto , japan , aug . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:10,961 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:10,963 [root]  	[INFO] - Run 17/50
#        INFO     2024-12-20 17:58:10,966 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'guest editor s introduction', 2002. Publication B is titled 'guest editorial', z bankowski , a scott , f snyder, european law journal ,, 1998.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:11,530 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:11,533 [root]  	[INFO] - Run 18/50
#        INFO     2024-12-20 17:58:11,538 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'catching the boat with strudel : experiences with a web-site management system', m fernandez , d florescu , j kang , a levy , d suciu, sigmod conference, 1998. Publication B is titled 'ã cents â ? ¬ å?catching the boat with strudel : experiences with a web-site management systemã cents â ? ¬ â ?', mf fernandez , d florescu , j kang , ay levy , d suciu, proc . of the acm sigmod. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:11,944 [utils.run_utils]  	[INFO] - Prediction: yes | Actual: yes
#        INFO     2024-12-20 17:58:11,951 [root]  	[INFO] - Run 19/50
#        INFO     2024-12-20 17:58:11,960 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'panel : future directions of database research - the vldb broadening strategy , part 2', m brodie, vldb, 2000. Publication B is titled 'future directions of database research', hj schek , ml brodieâ ? ¦, vldb , cairo . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:12,347 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:12,351 [root]  	[INFO] - Run 20/50
#        INFO     2024-12-20 17:58:12,361 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'semantic integration of environmental models for application to global information systems and decision-making', d mackay, sigmod record, 1999. Publication B is titled 'an application of judgemental modelling for strategic decision making in an international', ian hipkin, electronic markets ,, 1999.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#        INFO     2024-12-20 17:58:12,687 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:12,689 [root]  	[INFO] - Run 21/50
#        INFO     2024-12-20 17:58:12,695 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'materialized views selection in a multidimensional database', e baralis , s paraboschi , e teniente, vldb, 1997. Publication B is titled 'a foundation for multi-dimensional databases', m gyssens , lvs lakshmanan. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:13,065 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:13,067 [root]  	[INFO] - Run 22/50
#        INFO     2024-12-20 17:58:13,071 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'the ecrc multi database system', w jonker , h schќtz, sigmod conference, 1995. Publication B is titled 'the indiana center for database systems', j copler, acm sigmod record ,, 1991.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:13,478 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:13,480 [root]  	[INFO] - Run 23/50
#        INFO     2024-12-20 17:58:13,483 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'probview : a flexible probabilistic database system', l lakshmanan , n leone , r ross , v subrahmanian, acm trans . database syst ., 1997. Publication B is titled 'the theory of probabilistic databases', r cavallo , m pittarelli, vldb ,, 1987.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:13,882 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:13,889 [root]  	[INFO] - Run 24/50
#        INFO     2024-12-20 17:58:13,894 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'title , foreword', 1994. Publication B is titled 'foreword', cm christensen , d sundahl, bt technology journal ,, 2001.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:14,293 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:14,295 [root]  	[INFO] - Run 25/50
#        INFO     2024-12-20 17:58:14,299 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'cure : an efficient clustering algorithm for large databases', s guha , r rastogi , k shim, sigmod conference, 1998. Publication B is titled 'an efficient and scalable algorithm for clustering xml documents by structure', xml clustering, ieee transactions on knowledge and data engineering ,, 2004.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:14,702 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:14,705 [root]  	[INFO] - Run 26/50
#        INFO     2024-12-20 17:58:14,709 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'static detection of security flaws in object-oriented databases', k tajima, sigmod conference, 1996. Publication B is titled 'view definition in an object-oriented database', s monk, information and software technology . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:15,123 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:15,125 [root]  	[INFO] - Run 27/50
#        INFO     2024-12-20 17:58:15,130 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'view maintenance in a warehousing environment', y zhuge , h garcia-molina , j hammer , j widom, sigmod conference, 1995. Publication B is titled 'efficient data view maintenance warehouses', d agrawal , a el abbadi , a singh , t yurek, proc . acm sigmod . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:15,444 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:15,446 [root]  	[INFO] - Run 28/50
#        INFO     2024-12-20 17:58:15,449 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'dec data distributor : for data replication and data warehousing', d dietterich, sigmod conference, 1994. Publication B is titled 'pp. 1â ?? 12 . dietterich , dj 1994 . dec data distributor : for data replication and data warehousing', a canada, int . conf . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:15,761 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:15,763 [root]  	[INFO] - Run 29/50
#        INFO     2024-12-20 17:58:15,767 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'the ccube constraint object-oriented database system', a brodsky , v segal , j chen , p exarkhopoulo, sigmod conference, 1999. Publication B is titled 'the o2 object-oriented database system', f bancilhon, proceedings of the 1992 acm sigmod international conference & hellip ; ,, 1992.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:16,139 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:16,143 [root]  	[INFO] - Run 30/50
#        INFO     2024-12-20 17:58:16,146 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'advanced xml data processing - guest editor s introduction', k aberer, sigmod record, 2001. Publication B is titled 'advanced xml data processing :', k aberer, sigmod record ,, 2001.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:16,553 [utils.run_utils]  	[INFO] - Prediction: no | Actual: yes
#        INFO     2024-12-20 17:58:16,557 [root]  	[INFO] - Run 31/50
#        INFO     2024-12-20 17:58:16,560 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'dynamic load balancing in hierarchical parallel database systems', l bouganim , d florescu , p valduriez, vldb, 1996. Publication B is titled 'dynamic load balancing in parallel database systems', e rahm. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:17,259 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:17,260 [root]  	[INFO] - Run 32/50
#        INFO     2024-12-20 17:58:17,262 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'business-to-business interactions : issues and enabling technologies', b medjahed , b benatallah , a bouguettaya , a ngu , a elmagarmid, vldb j., 2003. Publication B is titled 'b 2 b interactions : issues and enabling technologies', b medjahed , b benatalla , a bouguettaya , ahh ngu ,, the vldb journal . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:17,570 [utils.run_utils]  	[INFO] - Prediction: no | Actual: yes
#        INFO     2024-12-20 17:58:17,572 [root]  	[INFO] - Run 33/50
#        INFO     2024-12-20 17:58:17,575 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'selectivity estimation in spatial databases', s acharya , v poosala , s ramaswamy, sigmod conference, 1999. Publication B is titled 'selectivity estimation using probabilistic models', l getoor , b taskar , d koller. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:17,980 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:17,990 [root]  	[INFO] - Run 34/50
#        INFO     2024-12-20 17:58:17,993 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'a cost model for clustered object-oriented databases', g gardarin , j gruser , z tang, vldb, 1995. Publication B is titled 'an axiomatic model for deductive object-oriented databases', zt kardkovacs , gm suranyi. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:18,347 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:18,348 [root]  	[INFO] - Run 35/50
#        INFO     2024-12-20 17:58:18,349 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'dimensionality reduction for similarity searching in dynamic databases', k kanth , d agrawal , a singh, sigmod conference, 1998. Publication B is titled 'dimensionalityreduction for similarity searching in dynamic databases', a singh , d agrawal , kvr kanth, acm. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:18,643 [utils.run_utils]  	[INFO] - Prediction: no | Actual: yes
#        INFO     2024-12-20 17:58:18,645 [root]  	[INFO] - Run 36/50
#        INFO     2024-12-20 17:58:18,648 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'extraction of object-oriented structures from existing relational databases', s ramanathan , j hodges, sigmod record, 1997. Publication B is titled 'extraction of object-oriented structures from existing relational databases', s ramanathan , j hodges, sigmod record ,, 1997.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:19,014 [utils.run_utils]  	[INFO] - Prediction: yes | Actual: yes
#        INFO     2024-12-20 17:58:19,015 [root]  	[INFO] - Run 37/50
#        INFO     2024-12-20 17:58:19,018 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'space optimization in deductive databases', d srivastava , s sudarshan , r ramakrishnan , j naughton, acm trans . database syst ., 1995. Publication B is titled 'binding propagation in disjunctive databases', s greco, vldb ,, 1998.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:19,411 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:19,413 [root]  	[INFO] - Run 38/50
#        INFO     2024-12-20 17:58:19,417 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'editorial', 2002. Publication B is titled 'editorial', s garrett , d sheat, bt technology journal ,, 2002.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:19,739 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:19,743 [root]  	[INFO] - Run 39/50
#        INFO     2024-12-20 17:58:19,746 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'mining generalized association rules', r srikant , r agrawal, vldb, 1995. Publication B is titled 'query flocks : a generalization of association-rule mining', s abitboul , c clifton , r motwani , s nestorov , d, & hellip ; of the acm international conference on management of data (. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:20,036 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:20,037 [root]  	[INFO] - Run 40/50
#        INFO     2024-12-20 17:58:20,040 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'aqr-toolkit : an adaptive query routing middleware for distributed data intensive systems', l liu , c pu , d buttler , w han , h paques , w tang, sigmod conference, 2000. Publication B is titled 'mocha : a self-extensible database middleware system for distributed data sources', mr martinez , n roussopoulos, acm sigmod international conference on management of data . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#        INFO     2024-12-20 17:58:20,405 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:20,408 [root]  	[INFO] - Run 41/50
#        INFO     2024-12-20 17:58:20,410 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'scalable parallel data mining for association rules', e han , g karypis , v kumar, sigmod conference, 1997. Publication B is titled 'mind : a scalable mining for classifier in relational databases', m wang , b iyer , js vitter, proceedings of the acm sigmod workshop on research issues on & hellip ; . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:23,106 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:23,110 [root]  	[INFO] - Run 42/50
#        INFO     2024-12-20 17:58:23,113 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'multiple-view self-maintenance in data warehousing environments', n huyn, vldb, 1997. Publication B is titled 'algorithms for materialized view design in data warehousing environment', j yang, vldb ,, 1997.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:25,591 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:25,593 [root]  	[INFO] - Run 43/50
#        INFO     2024-12-20 17:58:25,596 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'report on first international workshop on real-time database systems', 1996. Publication B is titled 'secure buffering in firm real-time database systems', b george , jr haritsa, the vldb journal the international journal on very large & hellip ; ,, 2000.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:25,946 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:25,951 [root]  	[INFO] - Run 44/50
#        INFO     2024-12-20 17:58:25,953 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'efficient schemes for managing multiversionxml documents', s chien , v tsotras , c zaniolo, vldb j., 2002. Publication B is titled 'efficient management of multiversion documents by object referencing', sy chien , vj tsotras , c zaniolo, proceedings of the international conference on very large & hellip ; ,, 2001.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:26,279 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:26,280 [root]  	[INFO] - Run 45/50
#        INFO     2024-12-20 17:58:26,287 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'size separation spatial join', n koudas , k sevcik, sigmod conference, 1997. Publication B is titled 'iterative spatial join', eh jacox , h samet, acm transactions on database systems ,, 2003.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:26,581 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:26,585 [root]  	[INFO] - Run 46/50
#        INFO     2024-12-20 17:58:26,588 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'naos - efficient and modular reactive capabilities in an object-oriented database system', c collet , t coupaye , t svensen, vldb, 1994. Publication B is titled 'object-oriented database systems : in transition', f bancilhon , w kim, sigmod record ,, 1990.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:27,317 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:27,319 [root]  	[INFO] - Run 47/50
#        INFO     2024-12-20 17:58:27,322 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'a logical foundation for deductive object-oriented databases', m liu , g dobbie , t ling, acm trans . database syst ., 2002. Publication B is titled 'query evaluation and optimization in deductive and object-oriented spatial databases', w lu , j han, information and software technology ,, 1995.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:27,608 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:27,610 [root]  	[INFO] - Run 48/50
#        INFO     2024-12-20 17:58:27,613 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'languages for multi-database interoperability', f gingras , l lakshmanan , i subramanian , d papoulis , n shiri, sigmod conference, 1997. Publication B is titled 'andi . n. subramanian . schemasql-a languagefor interoperabilityin relationalmulti-database systems', l lakshmanan , f sadri, proc . vldb conf . Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:28,007 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:28,008 [root]  	[INFO] - Run 49/50
#        INFO     2024-12-20 17:58:28,011 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'a performance study of transitive closure algorithms', s dar , r ramakrishnan, sigmod conference, 1994. Publication B is titled 'hybrid transitive closure algorithms', r agrawal , hv jagadish, vldb ,, 1990.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#
#
#        INFO     2024-12-20 17:58:28,292 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:28,294 [root]  	[INFO] - Run 50/50
#        INFO     2024-12-20 17:58:28,296 [utils.run_utils]  	[INFO] -
# <<<<<<<<<<< PROMPT START >>>>>>>>>>>
#
#               Are Publication A and Publication B the same? Yes or No? Publication A is titled 'relational data sharing in peer-based data management systems', b ooi , y shu , k tan, sigmod record, 2003. Publication B is titled 'query processing in a relational database management system', k youssefi , e wong, vldb ,, 1979.0. Are Publication A and Publication B the same?
#
# <<<<<<<<<<< PROMPT END >>>>>>>>>>>
#        INFO     2024-12-20 17:58:28,625 [utils.run_utils]  	[INFO] - Prediction: no | Actual: no
#        INFO     2024-12-20 17:58:28,626 [utils.run_utils]  	[INFO] - Final Metrics {
#                 "prec": [
#                                 1.0
#                 ],
#                 "rec": [
#                                 0.375
#                 ],
#                 "f1": [
#                                 0.5454545454545454
#                 ],
#                 "acc": [
#                                 0.9
#                 ],
#                 "time": [
#                                 26.634288541999922
#                 ]
# }
#        INFO     2024-12-20 17:58:28,627 [root]  	[INFO] - Getting file path
# 'output/output_basic_ctx/dblp_gs/gpt-3_k_0_n_50_natural_00.json'

# %% [markdown]
# ### Show results
